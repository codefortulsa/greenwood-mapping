# %%
import django_initializer

# %%
from buildings.models import Building
buildings = Building.objects.all()
buildings
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/venv/lib/python3.10/site-packages/django/db/backends/base/base.py:282, in BaseDatabaseWrapper.ensure_connection(self)
#     281 with self.wrap_database_errors:
# --> 282     self.connect()
#
# File /opt/venv/lib/python3.10/site-packages/django/utils/asyncio.py:26, in async_unsafe.<locals>.decorator.<locals>.inner(*args, **kwargs)
#      25 # Pass onward.
# ---> 26 return func(*args, **kwargs)
#
# File /opt/venv/lib/python3.10/site-packages/django/db/backends/base/base.py:263, in BaseDatabaseWrapper.connect(self)
#     262 conn_params = self.get_connection_params()
# --> 263 self.connection = self.get_new_connection(conn_params)
#     264 self.set_autocommit(self.settings_dict["AUTOCOMMIT"])
#
# ...
